# %%
sen = 'The sky cracked open with a quiet flash of silver,Even the wind seemed to pause'

# %%
sen.split()
# Out:
# ['The',
#  'sky',
#  'cracked',
#  'open',
#  'with',
#  'a',
#  'quiet',
#  'flash',
#  'of',
#  'silver,Even',
#  'the',
#  'wind',
#  'seemed',
#  'to',
#  'pause']

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
t_sen = word_tokenize(sen)
t_sen
# Out:
# ['The',
#  'sky',
#  'cracked',
#  'open',
#  'with',
#  'a',
#  'quiet',
#  'flash',
#  'of',
#  'silver',
#  ',',
#  'Even',
#  'the',
#  'wind',
#  'seemed',
#  'to',
#  'pause']

# %%
text = 'This is new text for ?spliting the sentence by stopword'
token = word_tokenize(text)

nltk.download('stopwords')  # dowload neccesarry libraries

stop_word = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
filtered_words = []

# %%
words = text.lower().split()

# %%
final = [i for i in token
 if i.lower() not in stop_word]

# %%
len(token)
# Out:
# 11

# %%
len(final)
# Out:
# 6

# %%
web_text = """ Data science is an interdisciplinary academic field[1] that uses statistics, scientific
computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or
extrapolate knowledge from potentially noisy, structured,
or unstructured data.[2]

Data science also integrates domain knowledge from the underlying application domain
(e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can
be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]"""

# %%
len(web_text)
# Out:
# 584

# %%
tokenize = word_tokenize(web_text)

# %%
def remove_stop(t):
 tokenize = word_tokenize(web_text)
 stop_word = set(stop_word.words('english'))
 sw = [word for word in tokenize if word.lower() not in stop_word]
 return sw

# %%
len(sw)
# Out:
# 83

# %%
import string

def removing(text):
  punctuation = string.punctuation
  for punc in list(punctuation):
    if punc in text :
      text = text.replace(punc,' ')
      return text

# %%
text
# Out:
# 'This is new text for ?spliting the sentence by stopword'

# %%
import re
def remove_html_tag(text):
  pattern = re.compile("<.*?")
  return pattern.sub(r'',text)

# %%
text = '<div class="mw-content-ltr mw-parser-output" lang="en" dir="ltr">…</div>'

# %%
remove_html_tag(text)
# Out:
# 'div class="mw-content-ltr mw-parser-output" lang="en" dir="ltr">…/div>'
